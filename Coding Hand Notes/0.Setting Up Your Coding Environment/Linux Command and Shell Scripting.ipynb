# %% [markdown]
# ### Introduction to Linux

# %% [markdown]
# ### Five Layers of Linux&emsp;
# The UI&emsp; User interface. Microsoft Windows is a GUI(graphical user interface)<br>
# Application&emsp; Shell is an OS level application that you can use to enter commands. Includes System daemonds, Shells, Apps, Tools<br>
# OS&emsp; the operating system runs on top of the kernal and is vital for system health and stability.<br>
# Kernal&emsp; the lowest level software that enables applications to interact with hardware<br>
# Hardware&emsp; indludes all the physical or electronic components of your PC.<br>

# %% [markdown]
# #### Linux File System
# `~`   &emsp;home directory<br>
# `/`   &emsp;root directory<br>
# `.`   &emsp;present working directory<br>
# `..`  &emsp;parent of present working directory<br>
# `/bin`&emsp;User binary files folder contains the codes your machine reads to run programs and execute commands<br>
# `/user`&emsp;contains user programs<br>
# `/home`&emsp;your personal working directory where you store all your personal files<br>
# `/boot`&emsp;system boot files<br>
# `/media`&emsp;USB drives, CD etc temporary files<br>

# %% [markdown]
# ### Linux Shell
#
# The Shell is an OS level app that interprets commands. Some popular shells are Bash and Zsh. You interact with a Linux shell through the terminal.

# %% [markdown]
# Use the sudo command to enable access to "super user" system admin tools. sudo = "Super-user do". Use the sudo command to activate the powerful apt command. Use apt to upgrade nano to its latest version. apt (Advanced Packaging Tool) is a powerful command line tool. You use it to perform system administration operations such as installing software packages, upgrading existing packages, and updating your system's package list index.
#
# `sudo apt update`&emsp;         fetch and display up-to-date information about all upgradable packages<br>
# `sudo apt upgrade nano`&emsp;   upgrade to the latest supported version of nano<br>
# `sudo apt install vim`&emsp;    install vim <br>
# `nano filename.txt`&emsp;       create a new text file and open it with nano<br>

# %% [markdown]
# ### Introduction to Linux Commands
# A shell is an interactive user interface. Use shell commands to navigate and work with files and directories.<br>
#
# ##### Get user info
# `whoami` &emsp; user name<br>
# `id` &emsp; user id and group id<br>
# `uname -a` &emsp; return operating system name, username, and other info<br>
# `ps` &emsp; running processes<br>
# `man` &emsp; read the manual for any command<br>
# &emsp;&emsp;`man top` &emsp; display reference manual for the command 'top'<br>
# &emsp;&emsp;`man -k .` &emsp; list available man pages, including a brief description for each command<br>
# `npm install -g tldr`&emsp; install a command-line tool to access TLDR Pages from your terminal<br>
# `tldr command_name`&emsp; Once you've installed the tool, you can use the tldr command to easily access the TLDR page of a command<br>
# `df`(disk-free) &emsp; check system disk, or mounted file systems usage<br>
# `ps` &emsp; monitor processes and resources usage<br>
# `top` &emsp; task manager, monitor processes and resources usage<br>
# `date` &emsp; print get today's date or extract information about the date; `date "+It's %A, the %j day of %Y"` print "It's Friday, the 097 day of 2023". Use `man date` to check how to use<br>
# `echo` &emsp; print string or variable value<br>
# &emsp;&emsp; `-e` option when working with special characters, for instance: `echo -e "\tThis will be printed \nin two lines"`
#
# ##### Working with files and directories
# Relative paths are relative to your current working directories, while absolute paths stand independently.<br>
#
# `cp`&emsp; copy file<br>
# `mv`&emsp; change file name or path<br>
# `mkdir`&emsp; create a new directory<br>
# `rmdir`&emsp; remove an empty directory<br>
# `rm`&emsp; delete file<br>
# `touch`&emsp; create empty file, update file timestamp<br>
# `chmod`&emsp; change/modify file permissions<br>
# `wc`&emsp; get counts of lines, words, characters in file<br>
# `grep`&emsp; get the lines of a file that match your desired criteria<br>
# `ls`&emsp; list files and directories in the current directory<br>
# &emsp;&emsp;`ls path_to_directory`&emsp; list files and directories in a directory<br>
# `pwd`&emsp; return path to present working directory<br>
# `find` &emsp; finds files in your directories<br>
# `cut`&emsp; extracts slices and fields from lines<br>
# `paste`&emsp; You can merge lines from different files<br>
# `cd child_directory`&emsp; change the current directory to a subdirectory<br>
# &emsp;&emsp;`cd ../`&emsp;              change up one level<br>
# &emsp;&emsp;`cd ~`&emsp;                change to home<br>
# &emsp;&emsp;`cd ../dir_2`&emsp;         Suppose you have two sibling directories dir_1 and dir_2 and your cwd is dir_1, enter this to change to dir_2<br>
# &emsp;&emsp;`cd -`&emsp;                change the cwd back to the directory you were in previously<br>
#
#
# ##### Printing file and string contents
# `cat`&emsp; print file contents<br>
# `more`&emsp; print file contents page by page<br>
# `head`&emsp; print first n lines of the file<br>
# `tail`&emsp; print last n lines of the file<br>
# `sort`&emsp; to view the lines of a file alphanumerically<br>
# `uniq`&emsp; to remove repeated lines from your view<br>
# `less`&emsp; displays the contents of a file one page at a time<br>
#
#
# ##### Compression and archiving
# `zip`&emsp; compresses files and folders prior to archiving them<br>
# `unzip` unpacks and decompresses a zipped archive<br>
# `tar` archives and compresses files and directories into a tarball. This can also decompress and unpack a tar.gz archive<br>
#
# ##### Networking
# `hostname`&emsp; print hostname<br>
# `ping`&emsp; send packets to URL and print response<br>
# `ifconfig`&emsp; display or configure system network interfaces<br>
# `curl`&emsp; display contents of file at a URL<br>
# `wget`&emsp; download file from URL<br>

# %% [markdown]
# ##### Pipes

# %%
# Find where the current Python is
# !which python
# Out:
# /Users/yu-shenglee/ENTER/bin/python

# %%
#binaries (/bin) are the packages and modules that are installed for the 
#current binaries, look into your binaries folder
# !ls -al '/Users/yu-shenglee/ENTER/bin'
# Out:
# total 160200
# drwxr-xr-x  624 yu-shenglee  staff    19968 Aug 11 19:56 .
# drwxr-xr-x   27 yu-shenglee  staff      864 Sep  2 16:49 ..
# -rwxrwxr-x    2 yu-shenglee  staff      627 Jun 16  2023 .anaconda-navigator-post-link.sh
# -rwxrwxr-x    2 yu-shenglee  staff      142 Jun 16  2023 .anaconda-navigator-pre-unlink.sh
# -rwxrwxr-x    2 yu-shenglee  staff      139 Sep 19  2022 .python.app-post-link.sh
# -rwxrwxr-x    2 yu-shenglee  staff       38 Sep 19  2022 .python.app-pre-unlink.sh
# -rwxrwxr-x    2 yu-shenglee  staff      379 Aug  2  2023 .scikit-learn-post-link.sh
# lrwxr-xr-x    1 yu-shenglee  staff        9 Aug 11 19:55 2to3 -> 2to3-3.11
# -rwxrwxr-x    1 yu-shenglee  staff      116 Aug 11 19:55 2to3-3.11
# -rwxrwxr-x    2 yu-shenglee  staff    71504 Aug 13  2021 JxrDecApp
# -rwxrwxr-x    2 yu-shenglee  staff    71744 Aug 13  2021 JxrEncApp
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 bzcmp -> bzdiff
# -rwxrwxr-x    2 yu-shenglee  staff     2140 Jun 20  2021 bzdiff
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 bzegrep -> bzgrep
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 bzfgrep -> bzgrep
# -rwxrwxr-x    2 yu-shenglee  staff     2054 Jun 20  2021 bzgrep
# -rwxrwxr-x    2 yu-shenglee  staff   146832 Jun 20  2021 bzip2
# -rwxrwxr-x    2 yu-shenglee  staff    69392 Jun 20  2021 bzip2recover
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 bzless -> bzmore
# -rwxrwxr-x    2 yu-shenglee  staff     1259 Jun 20  2021 bzmore
# -rwxrwxr-x    1 yu-shenglee  staff     6809 Aug 11 19:55 c_rehash
# -rwxrwxr-x    2 yu-shenglee  staff    79376 Aug 10  2022 canbusutil
# lrwxr-xr-x    1 yu-shenglee  staff        3 Aug 11 19:55 captoinfo -> tic
# -rwxrwxr-x    2 yu-shenglee  staff   211824 Aug 13  2021 cbrunsli
# -rwxrwxr-x    2 yu-shenglee  staff   216656 May 31  2023 certutil
# -rwxrwxr-x    1 yu-shenglee  staff      246 Aug 11 19:56 cftp
# -rwxrwxr-x    1 yu-shenglee  staff      244 Aug 11 19:56 chardetect
# lrwxr-xr-x    1 yu-shenglee  staff       36 Aug 11 19:56 check_dylib -> arm64-apple-darwin20.0.0-check_dylib
# lrwxr-xr-x    1 yu-shenglee  staff       34 Aug 11 19:56 checksyms -> arm64-apple-darwin20.0.0-checksyms
# -rwxrwxr-x    2 yu-shenglee  staff    87728 Mar  3  2023 cjpeg
# -rwxrwxr-x    1 yu-shenglee  staff      249 Aug 11 19:56 ckeygen
# -rwxrwxr-x    2 yu-shenglee  staff    68448 Jan 26  2023 clear
# lrwxr-xr-x    1 yu-shenglee  staff       33 Aug 11 19:56 cmpdylib -> arm64-apple-darwin20.0.0-cmpdylib
# lrwxr-xr-x    1 yu-shenglee  staff       42 Aug 11 19:56 codesign_allocate -> arm64-apple-darwin20.0.0-codesign_allocate
# -rwxrwxr-x    1 yu-shenglee  staff      239 Aug 11 19:56 colorcet
# -rwxrwxr-x    1 yu-shenglee  staff      837 Aug 11 19:55 compile_et
# -rwxrwxr-x    1 yu-shenglee  staff      247 Aug 11 19:56 conch
# -rwxrwxr-x    1 yu-shenglee  staff      525 Aug 11 19:56 conda
# -rwxrwxr-x    1 yu-shenglee  staff      248 Aug 11 19:56 conda-build
# -rwxr-xr-x    1 yu-shenglee  staff      246 Aug 11 19:56 conda-content-trust
# -rwxrwxr-x    1 yu-shenglee  staff      250 Aug 11 19:56 conda-convert
# -rwxrwxr-x    1 yu-shenglee  staff      248 Aug 11 19:56 conda-debug
# -rwxrwxr-x    1 yu-shenglee  staff      250 Aug 11 19:56 conda-develop
# -rwxrwxr-x    1 yu-shenglee  staff      162 Aug 11 19:56 conda-env
# -rwxrwxr-x    1 yu-shenglee  staff      248 Aug 11 19:56 conda-index
# -rwxrwxr-x    1 yu-shenglee  staff      250 Aug 11 19:56 conda-inspect
# -rwxrwxr-x    1 yu-shenglee  staff      254 Aug 11 19:56 conda-metapackage
# -rwxr-xr-x    1 yu-shenglee  staff      239 Aug 11 19:56 conda-pack
# -rwxrwxr-x    1 yu-shenglee  staff      249 Aug 11 19:56 conda-render
# -rwxrwxr-x    1 yu-shenglee  staff      235 Aug 11 19:56 conda-repo
# -rwxrwxr-x    1 yu-shenglee  staff      248 Aug 11 19:56
# -rwxrwxr-x    1 yu-shenglee  staff   113760 Aug 11 19:56 glib-compile-schemas
# -rwxrwxr-x    2 yu-shenglee  staff    41109 Nov 25  2022 glib-genmarshal
# -rwxrwxr-x    1 yu-shenglee  staff     5447 Aug 11 19:56 glib-gettextize
# -rwxrwxr-x    2 yu-shenglee  staff    30801 Nov 25  2022 glib-mkenums
# -rwxrwxr-x    2 yu-shenglee  staff    68016 Nov 25  2022 gobject-query
# -rwxrwxr-x    1 yu-shenglee  staff    86896 Aug 11 19:56 gresource
# -rwxrwxr-x    2 yu-shenglee  staff   129680 Feb  2  2023 grpc_cpp_plugin
# -rwxrwxr-x    2 yu-shenglee  staff    73984 Feb  2  2023 grpc_csharp_plugin
# -rwxrwxr-x    2 yu-shenglee  staff    73056 Feb  2  2023 grpc_node_plugin
# -rwxrwxr-x    2 yu-shenglee  staff    95488 Feb  2  2023 grpc_objective_c_plugin
# -rwxrwxr-x    2 yu-shenglee  staff    81248 Feb  2  2023 grpc_php_plugin
# -rwxrwxr-x    2 yu-shenglee  staff    68176 Feb  2  2023 grpc_python_plugin
# -rwxrwxr-x    2 yu-shenglee  staff    70528 Feb  2  2023 grpc_ruby_plugin
# -rwxrwxr-x    1 yu-shenglee  staff    90944 Aug 11 19:56 gsettings
# -rwxrwxr-x    2 yu-shenglee  staff    71152 Jun 16  2023 gss-client
# -rwxrwxr-x    2 yu-shenglee  staff    72480 Feb 23  2023 gst-device-monitor-1.0
# -rwxrwxr-x    2 yu-shenglee  staff    77120 Feb 23  2023 gst-discoverer-1.0
# -rwxrwxr-x    2 yu-shenglee  staff    97056 Feb 23  2023 gst-inspect-1.0
# -rwxrwxr-x    2 yu-shenglee  staff    77728 Feb 23  2023 gst-launch-1.0
# -rwxrwxr-x    2 yu-shenglee  staff    95280 Feb 23  2023 gst-play-1.0
# -rwxrwxr-x    2 yu-shenglee  staff    72368 Feb 23  2023 gst-stats-1.0
# -rwxrwxr-x    2 yu-shenglee  staff    70384 Feb 23  2023 gst-typefind-1.0
# -rwxrwxr-x    2 yu-shenglee  staff    72240 Nov 25  2022 gtester
# -rwxrwxr-x    2 yu-shenglee  staff    19095 Nov 25  2022 gtester-report
# -rwxrwxr-x    2 yu-shenglee  staff   209840 Jun 15  2022 h52gif
# -rwxrwxr-x    1 yu-shenglee  staff    13780 Aug 11 19:56 h5c++
# -rwxrwxr-x    1 yu-shenglee  staff    13477 Aug 11 19:56 h5cc
# -rwxrwxr-x    2 yu-shenglee  staff   209360 Jun 15  2022 h5clear
# -rwxrwxr-x    2 yu-shenglee  staff   209472 Jun 15  2022 h5copy
# -rwxrwxr-x    2 yu-shenglee  staff    70912 Jun 15  2022 h5debug
# -rwxrwxr-x    2 yu-shenglee  staff   294864 Jun 15  2022 h5diff
# -rwxrwxr-x    2 yu-shenglee  staff   280432 Jun 15  2022 h5dump
# -rwxrwxr-x    1 yu-shenglee  staff    12807 Aug 11 19:56 h5fc
# -rwxrwxr-x    2 yu-shenglee  staff   209296 Jun 15  2022 h5format_convert
# -rwxrwxr-x    2 yu-shenglee  staff   260752 Jun 15  2022 h5import
# -rwxrwxr-x    2 yu-shenglee  staff   209728 Jun 15  2022 h5jam
# -rwxrwxr-x    2 yu-shenglee  staff   229824 Jun 15  2022 h5ls
# -rwxrwxr-x    2 yu-shenglee  staff   209296 Jun 15  2022 h5mkgrp
# -rwxrwxr-x    2 yu-shenglee  staff   228528 Jun 15  2022 h5perf_serial
# -rwxrwxr-x    2 yu-shenglee  staff     5900 Jun 15  2022 h5redeploy
# -rwxrwxr-x    2 yu-shenglee  staff   314592 Jun 15  2022 h5repack
# -rwxrwxr-x    2 yu-shenglee  staff    69024 Jun 15  2022 h5repart
# -rwxrwxr-x    2 yu-shenglee  staff   227008 Jun 15  2022 h5stat
# -rwxrwxr-x    2 yu-shenglee  staff   209568 Jun 15  2022 h5unjam
# -rwxrwxr-x    2 yu-shenglee  staff   210128 Jun 15  2022 h5watch
# -rwxrwxr-x    1 yu-shenglee  staff      244 Aug 11 19:56 holoviews
# -rwxrwxr-x    1 yu-shenglee  staff      262 Aug 11 19:56 huggingface-cli
# -rwxrwxr-x    2 yu-shenglee  staff    71568 Apr 26  2022 iconv
# -rwxrwxr-x    1 yu-shenglee  staff    23308 Aug 11 19:55 icu-config
# -rwxrwxr-x    1 yu-shenglee  staff    85744 Aug 11 19:55 icuinfo
# lrwxr-xr-x    1 yu-shenglee  staff        8 Aug 11 19:55 idle3 -> idle3.11
# -rwxrwxr-x    1 yu-shenglee  staff      114 Aug 11 19:55 idle3.11
# -rwxrwxr-x    1 yu-shenglee  staff      242 Aug 11 19:56 imagecodecs
# -rwxrwxr-x    1 yu-shenglee  staff      264 Aug 11 19:56 imageio_download_bin
# -rwxrwxr-x    1 yu-shenglee  staff      260 Aug 11 19:56 imageio_remove_bin
# -rwxrwxr-x    1 yu-shenglee  staff    85984 Aug 11 19:56 imcopy
# -rwxrwxr-x    2 yu-shenglee  staff    93104 Feb 22  2023 img2webp
# lrwxr-xr-x    1 yu-shenglee  staff       29 Aug 11 19:56 indr -> arm64-apple-darwin20.0.0-indr
# -rwxrwxr-x    2 yu-shenglee  staff   104816 Jan 26  2023 infocmp
# lrwxr-xr-x    1 yu-shenglee  staff        3 Aug 11 19:55 infotocap -> tic
# lrwxr-xr-x    1 yu-shenglee  staff       30 Aug 11 19:56 inout -> arm64-apple-darwin20.0.0-inout
# lrwxr-xr-x    1 yu-shenglee  staff       42 Aug 11 19:56 install_name_tool -> arm64-apple-darwin20.0.0-install_name_tool
# -rwxrwxr-x    2 yu-shenglee  staff    69472 Oct 20  2022 installcheck
# -rwxrwxr-x    1 yu-shenglee  staff      248 Aug 11 19:56 intake
# -rwxrwxr-x    1 yu-shenglee  staff      248 Aug 11 19:56 intake-server
# -rwxrwxr-x    1 yu-shenglee  staff      247 Aug 11 19:56 ipython
# -rwxrwxr-x    1 yu-shenglee  staff      247 Aug 11 19:56 ipython3
# -rwxr-xr-x    1 yu-shenglee  staff      235 Aug 11 19:56 isort
# -rwxrwxr-x    1 yu-shenglee  staff      295 Aug 11 19:56 isort-identify-imports
# -rwxrwxr-x    2 yu-shenglee  staff    88544 Aug  3  2022 isql
# -rwxrwxr-x    1 yu-shenglee  staff      228 Aug 11 19:56 isympy
# -rwxrwxr-x    2 yu-shenglee  staff    72224 Jun 16  2023 klist
# -rwxrwxr-x    2 yu-shenglee  staff    69184 Jun 16  2023 kpasswd
# -rwxrwxr-x    1 yu-shenglee  staff     6902 Aug 11 19:55 krb5-config
# -rwxrwxr-x    2 yu-shenglee  staff    68176 Jun 16  2023 kswitch
# -rwxrwxr-x    2 yu-shenglee  staff    74480 Jun 16  2023 ktutil
# -rwxrwxr-x    2 yu-shenglee  staff    71248 Jun 16  2023 kvno
# -rwxrwxr-x    2 yu-shenglee  staff   745184 Aug 10  2022 lconvert
# lrwxr-xr-x    1 yu-shenglee  staff       27 Aug 11 19:56 ld -> arm64-apple-darwin20.0.0-ld
# -rwxrwxr-x    2 yu-shenglee  staff   172672 Jun 20  2023 ldid
# -rwxrwxr-x    2 yu-shenglee  staff    70560 Feb 27  2023 libdeflate-gunzip
# -rwxrwxr-x    2 yu-shenglee  staff    70544 Feb 27  2023 libdeflate-gzip
# lrwxr-xr-x    1 yu-shenglee  staff       15 Aug 11 19:55 libpng-config -> libpng16-config
# -rwxrwxr-x    1 yu-shenglee  staff     2333 Aug 11 19:55 libpng16-config
# lrwxr-xr-x    1 yu-shenglee  staff       32 Aug 11 19:56 libtool -> arm64-apple-darwin20.0.0-libtool
# -rwxrwxr-x    1 yu-shenglee  staff    89152 Aug 11 19:56 linkicc
# lrwxr-xr-x    1 yu-shenglee  staff       29 Aug 11 19:56 lipo -> arm64-apple-darwin20.0.0-lipo
# -rwxrwxr-x    2 yu-shenglee  staff   962368 Aug 10  2022 lprodump
# -rwxrwxr-x    2 yu-shenglee  staff   762240 Aug 10  2022 lrelease
# -rwxrwxr-x    2 yu-shenglee  staff   577200 Aug 10  2022 lrelease-pro
# -rwxr-xr-x    1 yu-shenglee  staff      241 Aug 11 19:56 lsm2bin
# -rwxrwxr-x    2 yu-shenglee  staff  1014256 Aug 10  2022 lupdate
# -rwxrwxr-x    2 yu-shenglee  staff   577184 Aug 10  2022 lupdate-pro
# -rwxrwxr-x    2 yu-shenglee  staff   282624 Dec 13  2022 lz4
# lrwxr-xr-x    1 yu-shenglee  staff        3 Aug 11 19:55 lz4c -> lz4
# lrwxr-xr-x    1 yu-shenglee  staff        3 Aug 11 19:55 lz4cat -> lz4
# lrwxr-xr-x    1 yu-shenglee  staff        2 Aug 11 19:55 lzcat -> xz
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 lzcmp -> xzdiff
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 lzdiff -> xzdiff
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 lzegrep -> xzgrep
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 lzfgrep -> xzgrep
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 lzgrep -> xzgrep
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 lzless -> xzless
# lrwxr-xr-x    1 yu-shenglee  staff        2 Aug 11 19:55 lzma -> xz
# -rwxrwxr-x    2 yu-shenglee  staff    68576 May  3  2023 lzmadec
# -rwxrwxr-x    2 yu-shenglee  staff    68368 May  3  2023 lzmainfo
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55
# lrwxr-xr-x    1 yu-shenglee  staff       27 Aug 11 19:56 nm -> arm64-apple-darwin20.0.0-nm
# lrwxr-xr-x    1 yu-shenglee  staff       31 Aug 11 19:56 nmedit -> arm64-apple-darwin20.0.0-nmedit
# -rwxr-xr-x    1 yu-shenglee  staff      270 Aug 11 19:56 normalizer
# -rwxrwxr-x    1 yu-shenglee  staff     2671 Aug 11 19:55 nspr-config
# -rwxrwxr-x    1 yu-shenglee  staff     2603 Aug 11 19:55 nss-config
# -rwxrwxr-x    1 yu-shenglee  staff      244 Aug 11 19:56 numba
# -rwxrwxr-x    1 yu-shenglee  staff    84944 Aug 11 19:55 odbc_config
# -rwxrwxr-x    2 yu-shenglee  staff    70208 Aug  3  2022 odbcinst
# -rwxrwxr-x    1 yu-shenglee  staff     1394 Aug 11 19:55 onig-config
# -rwxrwxr-x    2 yu-shenglee  staff   655712 Jun 16  2023 openssl
# -rwxrwxr-x    2 yu-shenglee  staff   160096 Aug 13  2021 opj_compress
# -rwxrwxr-x    2 yu-shenglee  staff   160992 Aug 13  2021 opj_decompress
# -rwxrwxr-x    2 yu-shenglee  staff   142928 Aug 13  2021 opj_dump
# -rwxrwxr-x    2 yu-shenglee  staff    75408 Feb 15  2023 orc-contents
# -rwxrwxr-x    2 yu-shenglee  staff    78096 Feb 15  2023 orc-memory
# -rwxrwxr-x    2 yu-shenglee  staff    79840 Feb 15  2023 orc-metadata
# -rwxrwxr-x    2 yu-shenglee  staff    75520 Feb 15  2023 orc-scan
# -rwxrwxr-x    2 yu-shenglee  staff    73280 Feb 15  2023 orc-statistics
# lrwxr-xr-x    1 yu-shenglee  staff       30 Aug 11 19:56 otool -> arm64-apple-darwin20.0.0-otool
# lrwxr-xr-x    1 yu-shenglee  staff       34 Aug 11 19:56 pagestuff -> arm64-apple-darwin20.0.0-pagestuff
# -rwxrwxr-x    2 yu-shenglee  staff    68640 Feb 27  2023 pal2rgb
# -rwxrwxr-x    1 yu-shenglee  staff      235 Aug 11 19:56 panel
# -rwxrwxr-x    1 yu-shenglee  staff      240 Aug 11 19:56 pasteurize
# -rwxrwxr-x    2 yu-shenglee  staff   245488 Aug 23  2021 patch
# -rwxrwxr-x    1 yu-shenglee  staff     2377 Aug 11 19:55 pcre-config
# -rwxrwxr-x    1 yu-shenglee  staff     2193 Aug 11 19:55 pcre2-config
# -rwxrwxr-x    2 yu-shenglee  staff    90112 Jan  5  2022 pcre2grep
# -rwxrwxr-x    2 yu-shenglee  staff   206480 Jan  5  2022 pcre2test
# -rwxrwxr-x    2 yu-shenglee  staff    89136 Aug 20  2021 pcregrep
# -rwxrwxr-x    2 yu-shenglee  staff   122624 Aug 20  2021 pcretest
# -rwxrwxr-x    1 yu-shenglee  staff      228 Aug 11 19:56 pep8
# -rwxrwxr-x    1 yu-shenglee  staff   107136 Aug 11 19:55 pg_config
# -rwxrwxr-x    1 yu-shenglee  staff      244 Aug 11 19:56 pip
# -rwxrwxr-x    1 yu-shenglee  staff      244 Aug 11 19:56
# -rwxrwxr-x    1 yu-shenglee  staff      270 Aug 11 19:56 qdarkstyle
# -rwxrwxr-x    1 yu-shenglee  staff      278 Aug 11 19:56 qdarkstyle.example
# -rwxrwxr-x    1 yu-shenglee  staff      276 Aug 11 19:56 qdarkstyle.utils
# -rwxrwxr-x    2 yu-shenglee  staff    99216 Aug 10  2022 qdbus
# -rwxrwxr-x    2 yu-shenglee  staff   994080 Aug 10  2022 qdbuscpp2xml
# drwxr-xr-x    3 yu-shenglee  staff       96 Aug 11 19:56 qdbusviewer.app
# -rwxrwxr-x    2 yu-shenglee  staff   994752 Aug 10  2022 qdbusxml2cpp
# -rwxrwxr-x    1 yu-shenglee  staff  1748304 Aug 11 19:56 qdoc
# -rwxrwxr-x    2 yu-shenglee  staff  4877472 Aug 10  2022 qgltf
# -rwxrwxr-x    2 yu-shenglee  staff   626224 Aug 10  2022 qlalr
# -rwxrwxr-x    2 yu-shenglee  staff  6226624 Aug 10  2022 qmake
# drwxr-xr-x    3 yu-shenglee  staff       96 Aug 11 19:56 qml.app
# -rwxrwxr-x    2 yu-shenglee  staff   996000 Aug 10  2022 qmlcachegen
# -rwxrwxr-x    2 yu-shenglee  staff   777888 Aug 10  2022 qmlformat
# -rwxrwxr-x    2 yu-shenglee  staff  1081152 Aug 10  2022 qmlimportscanner
# -rwxrwxr-x    2 yu-shenglee  staff   794736 Aug 10  2022 qmllint
# -rwxrwxr-x    2 yu-shenglee  staff   643984 Aug 10  2022 qmlmin
# -rwxrwxr-x    2 yu-shenglee  staff   122928 Aug 10  2022 qmlpreview
# -rwxrwxr-x    2 yu-shenglee  staff   103616 Aug 10  2022 qmlscene
# -rwxrwxr-x    2 yu-shenglee  staff    67056 Aug 10  2022 qmltestrunner
# -rwxrwxr-x    2 yu-shenglee  staff   660032 Aug 10  2022 qmltyperegistrar
# -rwxrwxr-x    2 yu-shenglee  staff   811168 Aug 10  2022 qscxmlc
# -rwxrwxr-x    1 yu-shenglee  staff      169 Aug 11 19:56 qt.conf
# -rwxrwxr-x    1 yu-shenglee  staff      242 Aug 11 19:56 qta-browser
# -rwxrwxr-x    2 yu-shenglee  staff   878432 Aug 10  2022 qtattributionsscanner
# -rwxrwxr-x    2 yu-shenglee  staff   107008 Aug 10  2022 qtdiag
# -rwxrwxr-x    2 yu-shenglee  staff    72512 Aug 10  2022 qtpaths
# -rwxrwxr-x    2 yu-shenglee  staff    74752 Aug 10  2022 qtplugininfo
# -rwxrwxr-x    1 yu-shenglee  staff      235 Aug 11 19:56 qtpy
# -rwxrwxr-x    2 yu-shenglee  staff   626016 Aug 10  2022 qvkgen
# lrwxr-xr-x    1 yu-shenglee  staff       31 Aug 11 19:56 ranlib -> arm64-apple-darwin20.0.0-ranlib
# -rwxrwxr-x    2 yu-shenglee  staff    68960 Feb 27  2023 raw2tiff
# -rwxrwxr-x    2 yu-shenglee  staff   710112 Aug 10  2022 rcc
# -rwxrwxr-x    2 yu-shenglee  staff    68000 Mar  3  2023 rdjpgcom
# -rwxrwxr-x    1 yu-shenglee  staff    86768 Aug 11 19:55 recode-sr-latin
# lrwxr-xr-x    1 yu-shenglee  staff       40 Aug 11 19:56 redo_prebinding -> arm64-apple-darwin20.0.0-redo_prebinding
# -rwxrwxr-x    1 yu-shenglee  staff  1056816 Aug 11 19:56 repc
# -rwxrwxr-x    2 yu-shenglee  staff    68592 Oct 20  2022 repo2solv
# lrwxr-xr-x    1 yu-shenglee  staff        4 Aug 11 19:55 reset -> tset
# -rwxrwxr-x    1 yu-shenglee  staff      613 Aug 11 19:56 rst2html.py
# -rwxrwxr-x    1 yu-shenglee  staff      733 Aug 11 19:56 rst2html4.py
# -rwxrwxr-x    1 yu-shenglee  staff     1101 Aug 11 19:56 rst2html5.py
# -rwxrwxr-x    1 yu-shenglee  staff      810 Aug 11 19:56 rst2latex.py
# -rwxrwxr-x    1 yu-shenglee  staff      618 Aug 11 19:56 rst2man.py
# -rwxrwxr-x    1 yu-shenglee  staff      783 Aug 11 19:56 rst2odt.py
# -rwxrwxr-x    1 yu-shenglee  staff     1745 Aug 11 19:56 rst2odt_prepstyles.py
# -rwxrwxr-x    1 yu-shenglee  staff      620 Aug 11 19:56 rst2pseudoxml.py
# -rwxrwxr-x    1 yu-shenglee  staff      656 Aug 11 19:56 rst2s5.py
# -rwxrwxr-x    1 yu-shenglee  staff      890 Aug 11 19:56 rst2xetex.py
# -rwxrwxr-x    1 yu-shenglee  staff      621 Aug 11 19:56 rst2xml.py
# -rwxrwxr-x    1 yu-shenglee  staff      689 Aug 11 19:56 rstpep2html.py
# -rwxr-xr-x    1 yu-shenglee  staff      237 Aug 11 19:56 sacremoses
# -rwxrwxr-x    1 yu-shenglee  staff      257 Aug 11 19:56 samp_hub
# -rwxrwxr-x    2 yu-shenglee  staff    68912 Jun 16  2023 sclient
# -rwxrwxr-x    1 yu-shenglee  staff      242 Aug 11 19:56 scrapy
# lrwxr-xr-x    1 yu-shenglee  staff       39 Aug 11 19:56 seg_addr_table -> arm64-apple-darwin20.0.0-seg_addr_table
# lrwxr-xr-x    1 yu-shenglee  staff       33 Aug 11 19:56 seg_hack -> arm64-apple-darwin20.0.0-seg_hack
# lrwxr-xr-x    1 yu-shenglee  staff       32 Aug 11 19:56 segedit -> arm64-apple-darwin20.0.0-segedit
# -rwxrwxr-x    1 yu-shenglee  staff      270 Aug 11 19:56 send2trash
# -rwxrwxr-x    1 yu-shenglee  staff      253 Aug 11 19:56 showtable
# -rwxrwxr-x    2 yu-shenglee  staff    68848 Jun 16  2023 sim_client
# -rwxrwxr-x    1 yu-shenglee  staff      242 Aug 11 19:56 sip-build
# -rwxrwxr-x    1 yu-shenglee  staff      244 Aug 11 19:56 sip-distinfo
# -rwxrwxr-x    1 yu-shenglee  staff      244 Aug 11 19:56 sip-install
# -rwxrwxr-x    1 yu-shenglee  staff      242 Aug 11 19:56 sip-module
# -rwxrwxr-x    1 yu-shenglee  staff      242 Aug 11 19:56 sip-sdist
# -rwxrwxr-x    1 yu-shenglee  staff      242 Aug 11 19:56 sip-wheel
# lrwxr-xr-x    1 yu-shenglee  staff       29 Aug 11 19:56 size -> arm64-apple-darwin20.0.0-size
# -rwxrwxr-x    1 yu-shenglee  staff      243 Aug 11 19:56 skivi
# -rwxrwxr-x    2 yu-shenglee  staff    68016 Aug  3  2022 slencheck
# -rwxr-xr-x    1 yu-shenglee  staff      241 Aug 11 19:56 slugify
# -rwxrwxr-x    1 yu-shenglee  staff    85216 Aug 11 19:56 smem
# -rwxrwxr-x    1 yu-shenglee  staff      239 Aug 11 19:56 sphinx-apidoc
# -rwxrwxr-x    1 yu-shenglee  staff      253 Aug 11 19:56 sphinx-autogen
# -rwxrwxr-x    1 yu-shenglee  staff      238 Aug 11 19:56 sphinx-build
# -rwxrwxr-x    1 yu-shenglee  staff      243 Aug 11 19:56 sphinx-quickstart
# -rwxrwxr-x    1 yu-shenglee  staff      249 Aug 11 19:56 spyder
# -rwxrwxr-x    2 yu-shenglee  staff  1809536 Apr 13  2023 sqlite3
# -rwxrwxr-x    2 yu-shenglee  staff    30392 Jun  1  2022 sqlite3_analyzer
# lrwxr-xr-x    1 yu-shenglee  staff       32 Aug 11 19:56 strings -> arm64-apple-darwin20.0.0-strings
# lrwxr-xr-x    1 yu-shenglee  staff       30 Aug 11 19:56 strip -> arm64-apple-darwin20.0.0-strip
# -rwxrwxr-x    1 yu-shenglee  staff      242 Aug 11 19:56 symilar
# -rwxrwxr-x    2 yu-shenglee  staff    48364 Oct 27  2020 syncqt.pl
# -rwxrwxr-x    2 yu-shenglee  staff    69136 Jan 26  2023 tabs
# -rwxrwxr-x    1 yu-shenglee  staff      232 Aug 11 19:56 tabulate
# lrwxr-xr-x    1 yu-shenglee  staff        8 Aug 11 19:55 tclsh -> tclsh8.6
# -rwxrwxr-x    2 yu-shenglee  staff    67360 Jun  1  2022 tclsh8.6
# -rwxrwxr-x    2 yu-shenglee  staff    70320 Oct 20  2022 testsolv
# -rwxrwxr-x    2 yu-shenglee  staff   123232 Jan 26  2023 tic
# -rwxrwxr-x    2 yu-shenglee  staff    68912 Feb 27  2023 tiff2bw
# -rwxr-xr-x    1 yu-shenglee  staff      245 Aug 11 19:56 tiff2fsspec
# -rwxrwxr-x    2 yu-shenglee  staff   124944 Feb 27  2023 tiff2pdf
# -rwxrwxr-x    2 yu-shenglee  staff   106256 Feb 27  2023 tiff2ps
# -rwxrwxr-x    2 yu-shenglee  staff    69536 Feb 27  2023 tiff2rgba
# -rwxrwxr-x    2 yu-shenglee  staff    68912 Feb 27  2023 tiffcmp
# -rwxr-xr-x    1 yu-shenglee  staff      245 Aug 11 19:56 tiffcomment
# -rwxrwxr-x    2 yu-shenglee  staff    89136 Feb 27  2023 tiffcp
# -rwxrwxr-x    2 yu-shenglee  staff   156304 Feb 27  2023 tiffcrop
# -rwxrwxr-x    2 yu-shenglee  staff    68736 Feb 27  2023 tiffdither
# -rwxrwxr-x    2 yu-shenglee  staff    69632 Feb 27  2023 tiffdump
# -rwxr-xr-x    1 yu-shenglee  staff      233 Aug 11 19:56 tifffile
# -rwxrwxr-x    2 yu-shenglee  staff    70832 Feb 27  2023 tiffinfo
# -rwxrwxr-x    2 yu-shenglee  staff    69024 Feb 27  2023 tiffmedian
# -rwxrwxr-x    2 yu-shenglee  staff    68864 Feb 27  2023 tiffset
# -rwxrwxr-x    2 yu-shenglee  staff    69408 Feb 27  2023 tiffsplit
# -rwxrwxr-x    1 yu-shenglee  staff    91264 Aug 11 19:56 tificc
# -rwxrwxr-x    2 yu-shenglee  staff    71840 Feb 15  2023 timezone-dump
# -rwxrwxr-x    1 yu-shenglee  staff      249 Aug 11 19:56 tkconch
# -rwxr-xr-x    1 yu-shenglee  staff      239 Aug 11 19:56 tldextract
# -rwxrwxr-x    2 yu-shenglee  staff    69856 Jan 26  2023 toe
# -rwxrwxr-x    1 yu-shenglee  staff      243 Aug 11 19:56 torchrun
# -rwxrwxr-x    2 yu-shenglee  staff    70736 Jan 26  2023 tput
# -rwxrwxr-x    1 yu-shenglee  staff      230 Aug 11 19:56 tqdm
# -rwxrwxr-x    2 yu-shenglee  staff   575552 Aug 10  2022 tracegen
# -rwxrwxr-x    1 yu-shenglee  staff      260 Aug 11 19:56 transformers-cli
# -rwxrwxr-x    1 yu-shenglee  staff   108016 Aug 11 19:56 transicc
# -rwxrwxr-x    1 yu-shenglee  staff      241 Aug 11 19:56 trial
# -rwxrwxr-x    2 yu-shenglee  staff    70544 Jan 26  2023 tset
# -rwxr-xr-x    1 yu-shenglee  staff      238 Aug 11 19:56 ttx
# -rwxrwxr-x    1 yu-shenglee  staff      261 Aug 11 19:56 twist
# -rwxrwxr-x    1 yu-shenglee  staff      242 Aug 11 19:56 twistd
# -rwxrwxr-x    2 yu-shenglee  staff   844224 Aug 10  2022 uic
# -rwxrwxr-x    1 yu-shenglee  staff      606 Aug 11 19:56 undill
# -rwxr-xr-x    1 yu-shenglee  staff      239 Aug 11 19:56 unidecode
# lrwxr-xr-x    1 yu-shenglee  staff        3 Aug 11 19:55 unlz4 -> lz4
# lrwxr-xr-x    1 yu-shenglee  staff        2 Aug 11 19:55 unlzma -> xz
# lrwxr-xr-x    1 yu-shenglee  staff       35 Aug 11 19:56 unwinddump -> arm64-apple-darwin20.0.0-unwinddump
# lrwxr-xr-x    1 yu-shenglee  staff        2 Aug 11 19:55 unxz -> xz
# lrwxr-xr-x    1 yu-shenglee  staff        4 Aug 11 19:55 unzstd -> zstd
# -rwxrwxr-x    2 yu-shenglee  staff    69696 Jun 16  2023 uuclient
# -rwxrwxr-x    1 yu-shenglee  staff      247 Aug 11 19:56 volint
# lrwxr-xr-x    1 yu-shenglee  staff       30 Aug 11 19:56 vtool -> arm64-apple-darwin20.0.0-vtool
# -rwxrwxr-x    1 yu-shenglee  staff      240 Aug 11 19:56 watchmedo
# -rwxrwxr-x    1 yu-shenglee  staff      241 Aug 11 19:56 wcslint
# -rwxrwxr-x    2 yu-shenglee  staff    85552 Feb 22  2023 webpinfo
# -rwxrwxr-x    2 yu-shenglee  staff    86944 Feb 22  2023 webpmux
# -rwxrwxr-x    1 yu-shenglee  staff      231 Aug 11 19:56 wheel
# lrwxr-xr-x    1 yu-shenglee  staff        7 Aug 11 19:55 wish -> wish8.6
# -rwxrwxr-x    2 yu-shenglee  staff    67776 Jun  1  2022 wish8.6
# -rwxrwxr-x    2 yu-shenglee  staff    68080 Mar  3  2023 wrjpgcom
# -rwxrwxr-x    2 yu-shenglee  staff     7251 Mar  4  2023 wsdump.py
# drwxr-xr-x    4 yu-shenglee  staff      128 Aug 11 19:56 xc-avoidance
# -rwxrwxr-x    1 yu-shenglee  staff   352144 Aug 11 19:55 xgettext
# -rwxrwxr-x    1 yu-shenglee  staff      233 Aug 11 19:56 xlwings
# -rwxrwxr-x    1 yu-shenglee  staff     1989 Aug 11 19:55 xml2-config
# -rwxrwxr-x    1 yu-shenglee  staff     1989 Aug 11 19:55 xml2-config.bak
# -rwxrwxr-x    1 yu-shenglee  staff    87280 Aug 11 19:55 xmlcatalog
# -rwxrwxr-x    1 yu-shenglee  staff   134608 Aug 11 19:55 xmllint
# -rwxrwxr-x    2 yu-shenglee  staff    96368 Aug 10  2022 xmlpatterns
# -rwxrwxr-x    2 yu-shenglee  staff    69424 Aug 10  2022 xmlpatternsvalidator
# -rwxrwxr-x    1 yu-shenglee  staff     2707 Aug 11 19:55 xslt-config
# -rwxrwxr-x    2 yu-shenglee  staff    72256 Mar 23  2023 xsltproc
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 xxh128sum -> xxhsum
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 xxh32sum -> xxhsum
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 xxh64sum -> xxhsum
# -rwxrwxr-x    2 yu-shenglee  staff   123376 Oct  1  2021 xxhsum
# -rwxrwxr-x    2 yu-shenglee  staff   130192 May  3  2023 xz
# lrwxr-xr-x    1 yu-shenglee  staff        2 Aug 11 19:55 xzcat -> xz
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 xzcmp -> xzdiff
# -rwxrwxr-x    2 yu-shenglee  staff    68576 May  3  2023 xzdec
# -rwxrwxr-x    2 yu-shenglee  staff     7422 May  3  2023 xzdiff
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 xzegrep -> xzgrep
# lrwxr-xr-x    1 yu-shenglee  staff        6 Aug 11 19:55 xzfgrep -> xzgrep
# -rwxrwxr-x    2 yu-shenglee  staff    10333 May  3  2023 xzgrep
# -rwxrwxr-x    2 yu-shenglee  staff     1813 May  3  2023 xzless
# -rwxrwxr-x    2 yu-shenglee  staff     2190 May  3  2023 xzmore
# -rwxr-xr-x    1 yu-shenglee  staff      237 Aug 11 19:56 yapf
# -rwxrwxr-x    1 yu-shenglee  staff      287 Aug 11 19:56 yapf-diff
# -rwxrwxr-x    1 yu-shenglee  staff    87776 Aug 11 19:55 zfp
# -rwxrwxr-x    2 yu-shenglee  staff    68064 Aug 13  2021 zopfli
# -rwxrwxr-x    2 yu-shenglee  staff    73840 Aug 13  2021 zopflipng
# -rwxrwxr-x    2 yu-shenglee  staff   222000 Apr 12  2023 zstd
# lrwxr-xr-x    1 yu-shenglee  staff        4 Aug 11 19:55 zstdcat -> zstd
# -rwxrwxr-x    2 yu-shenglee  staff     3869 Apr  4  2023 zstdgrep
# -rwxrwxr-x    2 yu-shenglee  staff      197 Apr  4  2023 zstdless
# lrwxr-xr-x    1 yu-shenglee  staff        4 Aug 11 19:55 zstdmt -> zstd

# %%
# !echo $PATH
# Out:
# /usr/local/bin:/Users/yu-shenglee/Library/Python/3.12/bin:/Users/yu-shenglee/ENTER/bin:/Users/yu-shenglee/ENTER/condabin:/Library/Frameworks/Python.framework/Versions/3.12/bin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Users/yu-shenglee/ENTER/bin:/Users/yu-shenglee/ENTER/condabin:/Library/Frameworks/Python.framework/Versions/3.12/bin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /Users/yu-shenglee/ENTER
